# %%
import gym
env = gym.make("CartPole-v0")

# %%
env.reset()

# %%
print("env.action_space: ", env.action_space)

# %%
#执行一个向左的操作
obj, reward, done, info = env.step(1) #1 向右 0向左
print("obj", obj) # 新状态
print("reward", reward) # 指定该动作获取的奖励值
print("done", done) # 回合是否结束
print("info", info) # 额外信息

# %%
#随机获取一个动作
action = env.action_space.sample()
print(action)

# %%
env.reset()
done = True

for step in range(50):
    # if step % 100 == 0:
    
    #     print(step//100)
    # print(step)
    if done:
        state = env.reset()
    action = env.action_space.sample()
    state, reward, done, info = env.step(action)
    print(action)
    print(state)
    print("reward", reward) # 指定该动作获取的奖励值

env.close()
# Out:
# 0
# [-0.03358403 -0.20950812 -0.04158562  0.23245944]
# reward 1.0
# 0
# [-0.03777419 -0.40401195 -0.03693643  0.5117403 ]
# reward 1.0
# 1
# [-0.04585443 -0.20838972 -0.02670163  0.20765025]
# reward 1.0
# 0
# [-0.05002222 -0.40311988 -0.02254862  0.49179202]
# reward 1.0
# 1
# [-0.05808462 -0.20768724 -0.01271278  0.19208886]
# reward 1.0
# 0
# [-0.06223836 -0.40262505 -0.008871    0.48073448]
# reward 1.0
# 1
# [-0.07029087 -0.207379    0.00074368  0.18526889]
# reward 1.0
# 0
# [-0.07443845 -0.40251159  0.00444906  0.47818633]
# reward 1.0
# 0
# [-0.08248868 -0.59769607  0.01401279  0.77226818]
# reward 1.0
# 0
# [-0.0944426  -0.793008    0.02945815  1.06932693]
# reward 1.0
# 0
# [-0.11030276 -0.98850691  0.05084469  1.37110752]
# reward 1.0
# 0
# [-0.1300729  -1.18422659  0.07826684  1.67924954]
# reward 1.0
# 0
# [-0.15375743 -1.38016368  0.11185183  1.99524241]
# reward 1.0
# 1
# [-0.1813607  -1.18637565  0.15175668  1.73919272]
# reward 1.0
# 1
# [-0.20508821 -0.99327364  0.18654054  1.49731408]
# reward 1.0
# 1
# [-0.22495369 -0.80084396  0.21648682  1.26820247]
# reward 1.0
# 1
# [ 0.04390316  0.1493734   0.01110318 -0.30586511]
# reward 1.0
# 1
# [ 0.04689063  0.34433538  0.00498588 -0.59502579]
# reward 1.0
# 1
# [ 0.05377734  0.5393872  -0.00691464 -0.88613404]
# reward 1.0
# 1
# [ 0.06456508  0.73460233 -0.02463732 -1.18098263]
# reward 1.0
# 0
# [ 0.07925713  0.5398087  -0.04825697 -0.8961235 ]
# reward 1.0
# 1
# [ 0.0900533   0.73555053 -0.06617944 -1.20357648]
# reward 1.0
# 0
# [ 0.10476431  0.54134361 -0.09025097 -0.93234635]
# reward 1.0
# 1
# [ 0.11559119  0.73755981 -0.1088979  -1.25197058]
# reward 1.0
# 0
# [ 0.13034238  0.5439884  -0.13393731 -0.99528614]
# reward 1.0
# 0
# [ 0.14122215  0.35088732 -0.15384303 -0.74748864]
# reward 1.0
# 1
# [ 0.1482399   0.54775917 -0.16879281 -1.08436032]
# reward 1.0
# 0
# [ 0.15919508  0.35521712 -0.19048001 -0.84904155]
# reward 1.0
# 0
# [ 0.16629942  0.16313199 -0.20746084 -0.62178818]
# reward 1.0
# 0
# [ 0.16956206 -0.02858185 -0.21989661 -0.40094067]
# reward 1.0
# 1
# [ 0.02559351  0.15185888  0.04765313 -0.31528479]
# reward 1.0
# 0
# [ 0.02863069 -0.04390833  0.04134743 -0.00796261]
# reward 1.0
# 1
# [ 0.02775252  0.150597    0.04118818 -0.28731856]
# reward 1.0
# 0
# [ 0.03076446 -0.04508739  0.03544181  0.01806498]
# reward 1.0
# 0
# [ 0.02986271 -0.24069922  0.03580311  0.32171618]
# reward 1.0
# 0
# [ 0.02504873 -0.43631225  0.04223743  0.62547154]
# reward 1.0
# 1
# [ 0.01632248 -0.24180458  0.05474686  0.34638437]
# reward 1.0
# 0
# [ 0.01148639 -0.4376608   0.06167455  0.65581607]
# reward 1.0
# 0
# [ 0.00273318 -0.63358469  0.07479087  0.96726398]
# reward 1.0
# 1
# [-0.00993852 -0.43954242  0.09413615  0.69898228]
# reward 1.0
# 1
# [-0.01872937 -0.24584298  0.1081158   0.4373547 ]
# reward 1.0
# 1
# [-0.02364623 -0.05240418  0.11686289  0.18061484]
# reward 1.0
# 0
# [-0.02469431 -0.24898764  0.12047519  0.50775831]
# reward 1.0
# 0
# [-0.02967406 -0.4455827   0.13063035  0.8358475 ]
# reward 1.0
# 0
# [-0.03858572 -0.64222392  0.1473473   1.16659244]
# reward 1.0
# 1
# [-0.0514302  -0.44929404  0.17067915  0.92349702]
# reward 1.0
# 1
# [-0.06041608 -0.25683756  0.18914909  0.68894338]
# reward 1.0
# 1
# [-0.06555283 -0.0647738   0.20292796  0.46126489]
# reward 1.0
# 1
# [-0.0668483   0.12698902  0.21215326  0.23877511]
# reward 1.0
# 1
# [-0.04905259  0.23824287 -0.02193466 -0.33494261]
# reward 1.0

# %%
import gym 
import torch
import torch.nn as nn 
import torch.nn.funtional as F
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\WINDOWS\TEMP/ipykernel_19904/1223209380.py in <module>
# ----> 1 import gym
#       2 import torch
#       3 import torch.nn as nn
#       4 import torch.nn.funtional as F
#
# ModuleNotFoundError: No module named 'gym'
